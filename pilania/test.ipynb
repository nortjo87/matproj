# %%
from pymatgen.core.periodic_table import Species

# %%
Species('Fe', oxidation_state=2).get_shannon_radius(cn="IVSQ",spin="High Spin")
# Out:
# 0.64

# %%
from mp_api.client import MPRester
with MPRester("6CO1jn2jJUru33xfX27JSfuiWfQIfdNu") as mpr:
    data = mpr.summary.search(
        formula="ABO3",
        fields=["material_id", "formula_pretty", "band_gap", "formation_energy_per_atom", 
                "energy_above_hull", "structure", "theoretical", "symmetry", "density"]
    )
# Out:
# C:\Users\snyil\AppData\Local\Temp\ipykernel_2576\2273272562.py:3: DeprecationWarning: Accessing summary data through MPRester.summary is deprecated. Please use MPRester.materials.summary instead.
#   data = mpr.summary.search(
# Retrieving SummaryDoc documents: 100%|██████████| 4700/4700 [00:08<00:00, 536.94it/s]

# %%
# Filter only perovskite-like
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
filtered = []
for entry in data:
    sga = SpacegroupAnalyzer(entry.structure)
    if "perovskite" in sga.get_crystal_system().lower() or entry.formula_pretty.endswith("O3"):
        filtered.append(entry)

# %%
len(filtered)
# Out:
# 2545

# %%
from matminer.data_retrieval.retrieve_MP import MPDataRetrieval
from mp_api.client import MPRester
import pandas as pd

API_KEY = "6CO1jn2jJUru33xfX27JSfuiWfQIfdNu"

# 🔹 Gunakan mp-api baru
mpr = MPRester(API_KEY)

# 🔹 Ambil data ABO3 dari Materials Project
results = mpr.summary.search(
    formula="ABO3",
    fields=[
        "material_id",
        "formula_pretty",
        "band_gap",
        "formation_energy_per_atom",
        "energy_above_hull",
        "structure",
        "theoretical",
        "symmetry",
        "density",
    ],
)

# 🔹 Konversi hasil jadi DataFrame (seperti Matminer)
df = pd.DataFrame([{
    "material_id": r.material_id,
    "formula": r.formula_pretty,
    "band_gap": r.band_gap,
    "formation_energy_per_atom": r.formulation_energy_per_atom if hasattr(r, "formation_energy_per_atom") else None,
    "energy_above_hull": r.energy_above_hull,
    "density": r.density,
    "symmetry": r.symmetry.symbol if hasattr(r, "symmetry") else None,
} for r in results])

# 🔹 Tampilkan hasil
print(df.head())
print(f"\nTotal data: {len(df)}")
# Out:
# C:\Users\snyil\AppData\Local\Temp\ipykernel_2576\3637294252.py:11: DeprecationWarning: Accessing summary data through MPRester.summary is deprecated. Please use MPRester.materials.summary instead.
#   results = mpr.summary.search(
# Retrieving SummaryDoc documents: 100%|██████████| 4700/4700 [00:13<00:00, 351.06it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 31
#      11 results = mpr.summary.search(
#      12     formula="ABO3",
#      13     fields=[
#    (...)     23     ],
#      24 )
#      26 # 🔹 Konversi hasil jadi DataFrame (seperti Matminer)
#      27 df = pd.DataFrame([{
#      28     "material_id": r.material_id,
#      29     "formula": r.formula_pretty,
#      30     "band_gap": r.band_gap,
# ---> 31     "formation_energy_per_atom": r.formulation_energy_per_atom if hasattr(r, "formation_energy_per_atom") else None,
#      32     "energy_above_hull": r.energy_above_hull,
#      33     "density": r.density,
#      34     "symmetry": r.symmetry.symbol if hasattr(r, "symmetry") else None,
#      35 } for r in results])
#      37 # 🔹 Tampilkan hasil
#      38 print(df.head())
#
# File c:\Users\snyil\miniconda3\envs\matproj\Lib\site-packages\mp_api\client\core\client.py:1132, in BaseRester._generate_returned_model.<locals>.new_getattr(self, attr)
#    1127     raise AttributeError(
#    1128         f"'{attr}' data is available but has not been requested in 'fields'."
#    1129         " A full list of unrequested fields can be found in `fields_not_requested`."
#    1130     )
#    1131 else:
# -> 1132     raise AttributeError(
#    1133         f"{self.__class__.__name__!r} object has no attribute {attr!r}"
#    1134     )
#
# AttributeError: 'MPDataDoc' object has no attribute 'formulation_energy_per_atom'
